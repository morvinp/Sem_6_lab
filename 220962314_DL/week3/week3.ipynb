# %% [markdown]
# ## Q1

# %%
import torch
import matplotlib.pyplot as plt

X = torch.tensor([12.4, 14.3, 14.5, 14.9, 16.1, 16.9, 16.5, 15.4, 17.0, 17.9, 18.8, 20.3, 22.4,
                  19.4, 15.5, 16.7, 17.3, 18.4, 19.2, 17.4, 19.5, 19.7, 21.2])

Y = torch.tensor([11.2, 12.5, 12.7, 13.1, 14.1, 14.8, 14.4, 13.4, 14.9, 15.6, 16.4, 17.7, 19.6,
                  16.9, 14.0, 14.6, 15.1, 16.1, 16.8, 15.2, 17.0, 17.2, 18.6])

w = torch.tensor(1.0, requires_grad=True)
b = torch.tensor(1.0, requires_grad=True)

def forward(x):
    return w * x + b

# Mean Square Error.
def criterion(Y_pred, y):
    return torch.mean((Y_pred - y) ** 2)

step_size = 0.001
loss_list = []
iter = 200

for i in range(iter):
    Y_pred = forward(X)
    loss = criterion(Y_pred, Y)
    loss_list.append(loss.item())
    loss.backward()
    w.data = w.data - step_size * w.grad.data
    b.data = b.data - step_size * b.grad.data

    w.grad.data.zero_()
    b.grad.data.zero_()

Y_pred_final = forward(X)

plt.scatter(X.numpy(), Y.numpy(), label='Data Points')
plt.plot(X.numpy(), Y_pred_final.detach().numpy(), color='orange', label='Fitted Line')
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()


plt.plot(loss_list, 'r')
plt.tight_layout()
plt.xlabel("Epochs/Iterations")
plt.ylabel("Loss")
plt.show()

# %% [markdown]
# ## Q2

# %%
import torch
import matplotlib.pyplot as plt

X = torch.tensor([2,4])

Y = torch.tensor([20,40])

w = torch.tensor(1.0, requires_grad=True)
b = torch.tensor(1.0, requires_grad=True)

step_size = 0.001
epochs = 2
loss_list = []

for epoch in range(epochs):
    Y_pred = w * X + b

    loss = torch.mean((Y_pred - Y) ** 2)
    loss_list.append(loss.item())

    loss.backward()

    print(f"Epoch {epoch + 1}:")
    print(f"  w.grad: {w.grad.item()}")
    print(f"  b.grad: {b.grad.item()}")  #

    with torch.no_grad():
        w -= step_size * w.grad
        b -= step_size * b.grad

    w.grad.zero_()
    b.grad.zero_()

    print(f"  Updated w: {w.item()}")
    print(f"  Updated b: {b.item()}")
    print('-' * 40)

plt.plot(loss_list, 'r')
plt.xlabel("Epochs/Iterations")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.show()
# Out:
# Epoch 1:
#   w.grad: -174.0
#   b.grad: -52.0
#   Updated w: 1.1740000247955322
#   Updated b: 1.0520000457763672
# ----------------------------------------
# Epoch 2:
#   w.grad: -170.20799255371094
#   b.grad: -50.85199737548828
#   Updated w: 1.344208002090454
#   Updated b: 1.1028521060943604
# ----------------------------------------

# %% [markdown]
# ## Q3

# %%
import torch
import matplotlib.pyplot as plt

x = torch.tensor([5.0, 7.0, 12.0, 16.0, 20.0])
y = torch.tensor([40.0, 120.0, 180.0, 210.0, 240.0])
lr = torch.tensor(0.001)

class RegressionModel:
    def __init__(self):
        self.w = torch.rand([1], requires_grad=True)
        self.b = torch.rand([1], requires_grad=True)

    def forward(self, x):
        return self.w*x+ self.b

    def update(self):
        self.w -= lr*self.w.grad
        self.b -= lr*self.b.grad

    def reset_grad(self):
        self.w.grad.zero_()
        self.b.grad.zero_()

def criterion(yj,y_p):
    return torch.mean(yj - y_p)**2

model = RegressionModel()

loss_list = []
for epochs in range(100):
    print(w,b)
    loss = 0
    for j in range(len(x)):
        y_p = model.forward(x[j])
        loss += criterion(y[j],y_p)
    loss = loss/len(x)
    loss_list.append(loss.item())

    loss.backward()

    with torch.no_grad():
        model.update()

    model.reset_grad()

plt.plot(loss_list)
plt.show()
# Out:
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)
# tensor(1.3442, requires_grad=True) tensor(1.1029, requires_grad=True)

# %% [markdown]
# ## Q4

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

x = torch.tensor([5.0, 7.0, 12.0, 16.0, 20.0]).view(-1, 1)  # Reshaped for NN input
y = torch.tensor([40.0, 120.0, 180.0, 210.0, 240.0]).view(-1, 1)

class RegressionModel(nn.Module):
    def __init__(self):
        super(RegressionModel, self).__init__()
#         self.linear = nn.Linear(1, 1)  # Linear model: y = wx + b
        self.w = torch.nn.Parameter(torch.rand([1]))
        self.b = torch.nn.Parameter(torch.rand([1]))
        
    def forward(self, x):
        print(self.w, self.b)
        return self.w*x + self.b

model = RegressionModel()

criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.001)

loss_list = []

for epoch in range(100):
    model.train()

    # Forward pass
    y_pred = model(x)
    loss = criterion(y_pred, y)

    optimizer.zero_grad()
    loss.backward()
    print(model.w.grad, model.b.grad)
    optimizer.step()
    loss_list.append(loss.item())

plt.plot(loss_list)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.show()

print("Learned weight:", model.w.item())
print("Learned bias:", model.b.item())
# Out:
# Parameter containing:
# tensor([0.9087], requires_grad=True) Parameter containing:
# tensor([0.3682], requires_grad=True)
# tensor([-4217.4727]) tensor([-293.4542])
# Parameter containing:
# tensor([5.1262], requires_grad=True) Parameter containing:
# tensor([0.6616], requires_grad=True)
# tensor([-2736.0010]) tensor([-191.6479])
# Parameter containing:
# tensor([7.8622], requires_grad=True) Parameter containing:
# tensor([0.8533], requires_grad=True)
# tensor([-1774.8955]) tensor([-125.6006])
# Parameter containing:
# tensor([9.6371], requires_grad=True) Parameter containing:
# tensor([0.9789], requires_grad=True)
# tensor([-1151.3777]) tensor([-82.7519])
# Parameter containing:
# tensor([10.7885], requires_grad=True) Parameter containing:
# tensor([1.0616], requires_grad=True)
# tensor([-746.8700]) tensor([-54.9533])
# Parameter containing:
# tensor([11.5353], requires_grad=True) Parameter containing:
# tensor([1.1166], requires_grad=True)
# tensor([-484.4452]) tensor([-36.9185])
# Parameter containing:
# tensor([12.0198], requires_grad=True) Parameter containing:
# tensor([1.1535], requires_grad=True)
# tensor([-314.1971]) tensor([-25.2180])
# Parameter containing:
# tensor([12.3340], requires_grad=True) Parameter containing:
# tensor([1.1787], requires_grad=True)
# tensor([-203.7483]) tensor([-17.6268])
# Parameter containing:
# tensor([12.5377], requires_grad=True) Parameter containing:
# tensor([1.1963], requires_grad=True)
# tensor([-132.0948]) tensor([-12.7016])
# Parameter containing:
# tensor([12.6698], requires_grad=True) Parameter containing:
# tensor([1.2090], requires_grad=True)
# tensor([-85.6099]) tensor([-9.5060])
# Parameter containing:
# tensor([12.7554], requires_grad=True) Parameter containing:
# tensor([1.2186], requires_grad=True)
# tensor([-55.4527]) tensor([-7.4323])
# Parameter containing:
# tensor([12.8109], requires_grad=True) Parameter containing:
# tensor([1.2260], requires_grad=True)
# tensor([-35.8881]) tensor([-6.0866])
# Parameter containing:
# tensor([12.8468], requires_grad=True) Parameter containing:
# tensor([1.2321], requires_grad=True)
# tensor([-23.1956]) tensor([-5.2131])
# Parameter containing:
# tensor([12.8700], requires_grad=True) Parameter containing:
# tensor([1.2373], requires_grad=True)
# tensor([-14.9614]) tensor([-4.6460])
# Parameter containing:
# tensor([12.8849], requires_grad=True) Parameter containing:
# tensor([1.2419], requires_grad=True)
# tensor([-9.6196]) tensor([-4.2776])
# Parameter containing:
# tensor([12.8946], requires_grad=True) Parameter containing:
# tensor([1.2462], requires_grad=True)
# tensor([-6.1537]) tensor([-4.0382])
# Parameter containing:
# tensor([12.9007], requires_grad=True) Parameter containing:
# tensor([1.2502], requires_grad=True)
# tensor([-3.9055]) tensor([-3.8824])
# Parameter containing:
# tensor([12.9046], requires_grad=True) Parameter containing:
# tensor([1.2541], requires_grad=True)
# tensor([-2.4471]) tensor([-3.7810])
# Parameter containing:
# tensor([12.9071], requires_grad=True) Parameter containing:
# tensor([1.2579], requires_grad=True)
# tensor([-1.5007]) tensor([-3.7147])
# Parameter containing:
# tensor([12.9086], requires_grad=True) Parameter containing:
# tensor([1.2616], requires_grad=True)
# tensor([-0.8868]) tensor([-3.6712])
# Parameter containing:
# tensor([12.9095], requires_grad=True) Parameter containing:
# tensor([1.2653], requires_grad=True)
# tensor([-0.4886]) tensor([-3.6426])
# Parameter containing:
# tensor([12.9099], requires_grad=True) Parameter containing:
# tensor([1.2689], requires_grad=True)
# tensor([-0.2305]) tensor([-3.6236])
# Parameter containing:
# tensor([12.9102], requires_grad=True) Parameter containing:
# tensor([1.2726], requires_grad=True)
# tensor([-0.0630]) tensor([-3.6108])
# Parameter containing:
# tensor([12.9102], requires_grad=True) Parameter containing:
# tensor([1.2762], requires_grad=True)
# tensor([0.0459]) tensor([-3.6020])
# Parameter containing:
# tensor([12.9102], requires_grad=True) Parameter containing:
# tensor([1.2798], requires_grad=True)
# tensor([0.1165]) tensor([-3.5959])
# Parameter containing:
# tensor([12.9101], requires_grad=True) Parameter containing:
# tensor([1.2834], requires_grad=True)
# tensor([0.1619]) tensor([-3.5915])
# Parameter containing:
# tensor([12.9099], requires_grad=True) Parameter containing:
# tensor([1.2870], requires_grad=True)
# tensor([0.1914]) tensor([-3.5882])
# Parameter containing:
# tensor([12.9097], requires_grad=True) Parameter containing:
# tensor([1.2906], requires_grad=True)
# tensor([0.2105]) tensor([-3.5857])
# Parameter containing:
# tensor([12.9095], requires_grad=True) Parameter containing:
# tensor([1.2941], requires_grad=True)
# tensor([0.2228]) tensor([-3.5836])
# Parameter containing:
# tensor([12.9093], requires_grad=True) Parameter containing:
# tensor([1.2977], requires_grad=True)
# tensor([0.2310]) tensor([-3.5817])
# Parameter containing:
# tensor([12.9091], requires_grad=True) Parameter containing:
# tensor([1.3013], requires_grad=True)
# tensor([0.2361]) tensor([-3.5801])
# Parameter containing:
# tensor([12.9088], requires_grad=True) Parameter containing:
# tensor([1.3049], requires_grad=True)
# tensor([0.2393]) tensor([-3.5786])
# Parameter containing:
# tensor([12.9086], requires_grad=True) Parameter containing:
# tensor([1.3085], requires_grad=True)
# tensor([0.2416]) tensor([-3.5772])
# Parameter containing:
# tensor([12.9083], requires_grad=True) Parameter containing:
# tensor([1.3120], requires_grad=True)
# tensor([0.2432]) tensor([-3.5759])
# Parameter containing:
# tensor([12.9081], requires_grad=True) Parameter containing:
# tensor([1.3156], requires_grad=True)
# tensor([0.2440]) tensor([-3.5745])
# Parameter containing:
# tensor([12.9078], requires_grad=True) Parameter containing:
# tensor([1.3192], requires_grad=True)
# tensor([0.2443]) tensor([-3.5733])
# Parameter containing:
# tensor([12.9076], requires_grad=True) Parameter containing:
# tensor([1.3228], requires_grad=True)
# tensor([0.2449]) tensor([-3.5720])
# Parameter containing:
# tensor([12.9074], requires_grad=True) Parameter containing:
# tensor([1.3263], requires_grad=True)
# tensor([0.2448]) tensor([-3.5707])
# Parameter containing:
# tensor([12.9071], requires_grad=True) Parameter containing:
# tensor([1.3299], requires_grad=True)
# tensor([0.2448]) tensor([-3.5694])
# Parameter containing:
# tensor([12.9069], requires_grad=True) Parameter containing:
# tensor([1.3335], requires_grad=True)
# tensor([0.2449]) tensor([-3.5682])
# Parameter containing:
# tensor([12.9066], requires_grad=True) Parameter containing:
# tensor([1.3370], requires_grad=True)
# tensor([0.2448]) tensor([-3.5669])
# Parameter containing:
# tensor([12.9064], requires_grad=True) Parameter containing:
# tensor([1.3406], requires_grad=True)
# tensor([0.2445]) tensor([-3.5657])
# Parameter containing:
# tensor([12.9061], requires_grad=True) Parameter containing:
# tensor([1.3442], requires_grad=True)
# tensor([0.2448]) tensor([-3.5644])
# Parameter containing:
# tensor([12.9059], requires_grad=True) Parameter containing:
# tensor([1.3477], requires_grad=True)
# tensor([0.2449]) tensor([-3.5632])
# Parameter containing:
# tensor([12.9056], requires_grad=True) Parameter containing:
# tensor([1.3513], requires_grad=True)
# tensor([0.2447]) tensor([-3.5619])
# Parameter containing:
# tensor([12.9054], requires_grad=True) Parameter containing:
# tensor([1.3549], requires_grad=True)
# tensor([0.2443]) tensor([-3.5607])
# Parameter containing:
# tensor([12.9052], requires_grad=True) Parameter containing:
# tensor([1.3584], requires_grad=True)
# tensor([0.2444]) tensor([-3.5594])
# Parameter containing:
# tensor([12.9049], requires_grad=True) Parameter containing:
# tensor([1.3620], requires_grad=True)
# tensor([0.2445]) tensor([-3.5582])
# Parameter containing:
# tensor([12.9047], requires_grad=True) Parameter containing:
# tensor([1.3655], requires_grad=True)
# tensor([0.2444]) tensor([-3.5569])
# Parameter containing:
# tensor([12.9044], requires_grad=True) Parameter containing:
# tensor([1.3691], requires_grad=True)
# tensor([0.2445]) tensor([-3.5557])
# Parameter containing:
# tensor([12.9042], requires_grad=True) Parameter containing:
# tensor([1.3727], requires_grad=True)
# tensor([0.2444]) tensor([-3.5544])
# Parameter containing:
# tensor([12.9039], requires_grad=True) Parameter containing:
# tensor([1.3762], requires_grad=True)
# tensor([0.2445]) tensor([-3.5532])
# Parameter containing:
# tensor([12.9037], requires_grad=True) Parameter containing:
# tensor([1.3798], requires_grad=True)
# tensor([0.2443]) tensor([-3.5519])
# Parameter containing:
# tensor([12.9034], requires_grad=True) Parameter containing:
# tensor([1.3833], requires_grad=True)
# tensor([0.2444]) tensor([-3.5507])
# Parameter containing:
# tensor([12.9032], requires_grad=True) Parameter containing:
# tensor([1.3869], requires_grad=True)
# tensor([0.2442]) tensor([-3.5494])
# Parameter containing:
# tensor([12.9030], requires_grad=True) Parameter containing:
# tensor([1.3904], requires_grad=True)
# tensor([0.2439]) tensor([-3.5482])
# Parameter containing:
# tensor([12.9027], requires_grad=True) Parameter containing:
# tensor([1.3940], requires_grad=True)
# tensor([0.2437]) tensor([-3.5469])
# Parameter containing:
# tensor([12.9025], requires_grad=True) Parameter containing:
# tensor([1.3975], requires_grad=True)
# tensor([0.2436]) tensor([-3.5457])
# Parameter containing:
# tensor([12.9022], requires_grad=True) Parameter containing:
# tensor([1.4011], requires_grad=True)
# tensor([0.2438]) tensor([-3.5444])
# Parameter containing:
# tensor([12.9020], requires_grad=True) Parameter containing:
# tensor([1.4046], requires_grad=True)
# tensor([0.2434]) tensor([-3.5432])
# Parameter containing:
# tensor([12.9017], requires_grad=True) Parameter containing:
# tensor([1.4081], requires_grad=True)
# tensor([0.2434]) tensor([-3.5420])
# Parameter containing:
# tensor([12.9015], requires_grad=True) Parameter containing:
# tensor([1.4117], requires_grad=True)
# tensor([0.2433]) tensor([-3.5407])
# Parameter containing:
# tensor([12.9013], requires_grad=True) Parameter containing:
# tensor([1.4152], requires_grad=True)
# tensor([0.2433]) tensor([-3.5395])
# Parameter containing:
# tensor([12.9010], requires_grad=True) Parameter containing:
# tensor([1.4188], requires_grad=True)
# tensor([0.2434]) tensor([-3.5382])
# Parameter containing:
# tensor([12.9008], requires_grad=True) Parameter containing:
# tensor([1.4223], requires_grad=True)
# tensor([0.2432]) tensor([-3.5370])
# Parameter containing:
# tensor([12.9005], requires_grad=True) Parameter containing:
# tensor([1.4258], requires_grad=True)
# tensor([0.2431]) tensor([-3.5358])
# Parameter containing:
# tensor([12.9003], requires_grad=True) Parameter containing:
# tensor([1.4294], requires_grad=True)
# tensor([0.2432]) tensor([-3.5345])
# Parameter containing:
# tensor([12.9000], requires_grad=True) Parameter containing:
# tensor([1.4329], requires_grad=True)
# tensor([0.2428]) tensor([-3.5333])
# Parameter containing:
# tensor([12.8998], requires_grad=True) Parameter containing:
# tensor([1.4364], requires_grad=True)
# tensor([0.2425]) tensor([-3.5321])
# Parameter containing:
# tensor([12.8996], requires_grad=True) Parameter containing:
# tensor([1.4400], requires_grad=True)
# tensor([0.2425]) tensor([-3.5308])
# Parameter containing:
# tensor([12.8993], requires_grad=True) Parameter containing:
# tensor([1.4435], requires_grad=True)
# tensor([0.2428]) tensor([-3.5296])
# Parameter containing:
# tensor([12.8991], requires_grad=True) Parameter containing:
# tensor([1.4470], requires_grad=True)
# tensor([0.2425]) tensor([-3.5283])
# Parameter containing:
# tensor([12.8988], requires_grad=True) Parameter containing:
# tensor([1.4506], requires_grad=True)
# tensor([0.2423]) tensor([-3.5271])
# Parameter containing:
# tensor([12.8986], requires_grad=True) Parameter containing:
# tensor([1.4541], requires_grad=True)
# tensor([0.2424]) tensor([-3.5259])
# Parameter containing:
# tensor([12.8983], requires_grad=True) Parameter containing:
# tensor([1.4576], requires_grad=True)
# tensor([0.2424]) tensor([-3.5246])
# Parameter containing:
# tensor([12.8981], requires_grad=True) Parameter containing:
# tensor([1.4611], requires_grad=True)
# tensor([0.2423]) tensor([-3.5234])
# Parameter containing:
# tensor([12.8979], requires_grad=True) Parameter containing:
# tensor([1.4647], requires_grad=True)
# tensor([0.2421]) tensor([-3.5221])
# Parameter containing:
# tensor([12.8976], requires_grad=True) Parameter containing:
# tensor([1.4682], requires_grad=True)
# tensor([0.2418]) tensor([-3.5209])
# Parameter containing:
# tensor([12.8974], requires_grad=True) Parameter containing:
# tensor([1.4717], requires_grad=True)
# tensor([0.2418]) tensor([-3.5197])
# Parameter containing:
# tensor([12.8971], requires_grad=True) Parameter containing:
# tensor([1.4752], requires_grad=True)
# tensor([0.2415]) tensor([-3.5185])
# Parameter containing:
# tensor([12.8969], requires_grad=True) Parameter containing:
# tensor([1.4787], requires_grad=True)
# tensor([0.2417]) tensor([-3.5172])
# Parameter containing:
# tensor([12.8966], requires_grad=True) Parameter containing:
# tensor([1.4823], requires_grad=True)
# tensor([0.2419]) tensor([-3.5160])
# Parameter containing:
# tensor([12.8964], requires_grad=True) Parameter containing:
# tensor([1.4858], requires_grad=True)
# tensor([0.2413]) tensor([-3.5148])
# Parameter containing:
# tensor([12.8962], requires_grad=True) Parameter containing:
# tensor([1.4893], requires_grad=True)
# tensor([0.2414]) tensor([-3.5135])
# Parameter containing:
# tensor([12.8959], requires_grad=True) Parameter containing:
# tensor([1.4928], requires_grad=True)
# tensor([0.2414]) tensor([-3.5123])
# Parameter containing:
# tensor([12.8957], requires_grad=True) Parameter containing:
# tensor([1.4963], requires_grad=True)
# tensor([0.2413]) tensor([-3.5110])
# Parameter containing:
# tensor([12.8954], requires_grad=True) Parameter containing:
# tensor([1.4998], requires_grad=True)
# tensor([0.2411]) tensor([-3.5098])
# Parameter containing:
# tensor([12.8952], requires_grad=True) Parameter containing:
# tensor([1.5033], requires_grad=True)
# tensor([0.2411]) tensor([-3.5086])
# Parameter containing:
# tensor([12.8950], requires_grad=True) Parameter containing:
# tensor([1.5069], requires_grad=True)
# tensor([0.2410]) tensor([-3.5074])
# Parameter containing:
# tensor([12.8947], requires_grad=True) Parameter containing:
# tensor([1.5104], requires_grad=True)
# tensor([0.2407]) tensor([-3.5061])
# Parameter containing:
# tensor([12.8945], requires_grad=True) Parameter containing:
# tensor([1.5139], requires_grad=True)
# tensor([0.2408]) tensor([-3.5049])
# Parameter containing:
# tensor([12.8942], requires_grad=True) Parameter containing:
# tensor([1.5174], requires_grad=True)
# tensor([0.2409]) tensor([-3.5037])
# Parameter containing:
# tensor([12.8940], requires_grad=True) Parameter containing:
# tensor([1.5209], requires_grad=True)
# tensor([0.2407]) tensor([-3.5024])
# Parameter containing:
# tensor([12.8938], requires_grad=True) Parameter containing:
# tensor([1.5244], requires_grad=True)
# tensor([0.2408]) tensor([-3.5012])
# Parameter containing:
# tensor([12.8935], requires_grad=True) Parameter containing:
# tensor([1.5279], requires_grad=True)
# tensor([0.2409]) tensor([-3.5000])
# Parameter containing:
# tensor([12.8933], requires_grad=True) Parameter containing:
# tensor([1.5314], requires_grad=True)
# tensor([0.2403]) tensor([-3.4988])
# Parameter containing:
# tensor([12.8930], requires_grad=True) Parameter containing:
# tensor([1.5349], requires_grad=True)
# tensor([0.2405]) tensor([-3.4975])
# Parameter containing:
# tensor([12.8928], requires_grad=True) Parameter containing:
# tensor([1.5384], requires_grad=True)
# tensor([0.2402]) tensor([-3.4963])
# Parameter containing:
# tensor([12.8925], requires_grad=True) Parameter containing:
# tensor([1.5419], requires_grad=True)
# tensor([0.2402]) tensor([-3.4951])
# Parameter containing:
# tensor([12.8923], requires_grad=True) Parameter containing:
# tensor([1.5454], requires_grad=True)
# tensor([0.2402]) tensor([-3.4938])
# Learned weight: 12.892068862915039
# Learned bias: 1.5488603115081787

# %% [markdown]
# ## Q5

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

X = torch.tensor([12.4, 14.3, 14.5, 14.9, 16.1, 16.9, 16.5, 15.4, 17.0, 17.9, 18.8, 20.3, 22.4,
                  19.4, 15.5, 16.7, 17.3, 18.4, 19.2, 17.4, 19.5, 19.7, 21.2]).view(-1, 1)  # Reshape for NN input
Y = torch.tensor([11.2, 12.5, 12.7, 13.1, 14.1, 14.8, 14.4, 13.4, 14.9, 15.6, 16.4, 17.7, 19.6,
                  16.9, 14.0, 14.6, 15.1, 16.1, 16.8, 15.2, 17.0, 17.2, 18.6]).view(-1, 1)  # Reshape for NN output

class LinearRegressionModel(nn.Module):
    def __init__(self):
        super(LinearRegressionModel, self).__init__()
        self.linear = nn.Linear(1, 1)  # Linear model: y = wx + b

    def forward(self, x):
        return self.linear(x)

model = LinearRegressionModel()

criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.001)
loss_list = []

for epoch in range(200):
    model.train()

    Y_pred = model(X)
    loss = criterion(Y_pred, Y)
    optimizer.zero_grad()
    loss.backward()
    print(model.linear.weight.item(), model.linear.bias.item())
    optimizer.step()
    loss_list.append(loss.item())

Y_pred_final = model(X).detach()

plt.scatter(X.numpy(), Y.numpy(), label='Data Points')
plt.plot(X.numpy(), Y_pred_final.numpy(), color='orange', label='Fitted Line')
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

plt.plot(loss_list, 'r')
plt.tight_layout()
plt.xlabel("Epochs/Iterations")
plt.ylabel("Loss")
plt.show()

print("Learned weight (w):", model.linear.weight.item())
print("Learned bias (b):", model.linear.bias.item())
# Out:
# 0.40839695930480957 -0.7191623449325562
# 0.7237389087677002 -0.701389491558075
# 0.8425649404525757 -0.6946672201156616
# 0.8873396515846252 -0.6921090483665466
# 0.9042102694511414 -0.6911199688911438
# 0.9105660915374756 -0.6907221674919128
# 0.9129596948623657 -0.6905471682548523
# 0.9138602614402771 -0.6904561519622803
# 0.9141981601715088 -0.690396785736084
# 0.9143241047859192 -0.6903493404388428
# 0.9143701195716858 -0.6903063654899597
# 0.9143860936164856 -0.6902651190757751
# 0.9143906831741333 -0.6902244687080383
# 0.9143909811973572 -0.6901840567588806
# 0.9143896698951721 -0.6901437640190125
# 0.9143877625465393 -0.6901035308837891
# 0.9143856763839722 -0.6900632977485657
# 0.9143834710121155 -0.6900230646133423
# 0.9143812656402588 -0.6899828314781189
# 0.9143790006637573 -0.6899425983428955
# 0.9143767356872559 -0.6899023652076721
# 0.9143744707107544 -0.6898621320724487
# 0.9143722057342529 -0.6898218989372253
# 0.9143699407577515 -0.689781665802002
# 0.91436767578125 -0.6897414326667786
# 0.9143654108047485 -0.6897011995315552
# 0.9143631458282471 -0.6896609663963318
# 0.9143608808517456 -0.6896207332611084
# 0.9143586158752441 -0.689580500125885
# 0.9143563508987427 -0.6895402669906616
# 0.9143540859222412 -0.6895000338554382
# 0.9143518209457397 -0.6894598007202148
# 0.9143495559692383 -0.6894195675849915
# 0.9143472909927368 -0.6893793344497681
# 0.9143450260162354 -0.6893391013145447
# 0.9143427610397339 -0.6892988681793213
# 0.9143404960632324 -0.6892586350440979
# 0.914338231086731 -0.6892184019088745
# 0.9143359661102295 -0.6891781687736511
# 0.9143337607383728 -0.6891379356384277
# 0.9143314957618713 -0.6890977621078491
# 0.9143292307853699 -0.6890575885772705
# 0.9143269658088684 -0.6890174150466919
# 0.9143247008323669 -0.6889772415161133
# 0.9143224358558655 -0.6889370679855347
# 0.914320170879364 -0.688896894454956
# 0.9143179059028625 -0.6888567209243774
# 0.9143156409263611 -0.6888165473937988
# 0.9143133759498596 -0.6887763738632202
# 0.9143111109733582 -0.6887362003326416
# 0.9143088459968567 -0.688696026802063
# 0.9143065810203552 -0.6886558532714844
# 0.9143043756484985 -0.6886156797409058
# 0.9143021106719971 -0.6885755062103271
# 0.9142998456954956 -0.6885353326797485
# 0.9142975807189941 -0.6884951591491699
# 0.9142953157424927 -0.6884549856185913
# 0.9142930507659912 -0.6884148120880127
# 0.9142907857894897 -0.6883746385574341
# 0.9142885208129883 -0.6883344650268555
# 0.9142862558364868 -0.6882942914962769
# 0.9142839908599854 -0.6882541179656982
# 0.9142817854881287 -0.6882139444351196
# 0.9142795205116272 -0.688173770904541
# 0.9142772555351257 -0.6881335973739624
# 0.9142749905586243 -0.6880934238433838
# 0.9142727255821228 -0.6880532503128052
# 0.9142704606056213 -0.6880130767822266
# 0.9142681956291199 -0.687972903251648
# 0.9142659902572632 -0.6879327297210693
# 0.9142637252807617 -0.6878925561904907
# 0.9142614603042603 -0.6878523826599121
# 0.9142591953277588 -0.6878122091293335
# 0.9142569303512573 -0.6877720355987549
# 0.9142546653747559 -0.6877318620681763
# 0.9142524003982544 -0.6876916885375977
# 0.9142501354217529 -0.687651515007019
# 0.9142478704452515 -0.6876113414764404
# 0.91424560546875 -0.6875711679458618
# 0.9142433404922485 -0.6875309944152832
# 0.9142410755157471 -0.6874908208847046
# 0.9142388105392456 -0.6874507069587708
# 0.9142365455627441 -0.6874105930328369
# 0.9142343401908875 -0.6873704791069031
# 0.914232075214386 -0.6873303651809692
# 0.9142298102378845 -0.6872902512550354
# 0.9142275452613831 -0.6872501373291016
# 0.9142253398895264 -0.6872100234031677
# 0.9142230749130249 -0.6871699094772339
# 0.9142208099365234 -0.6871297955513
# 0.914218544960022 -0.6870896816253662
# 0.9142162799835205 -0.6870495676994324
# 0.9142140746116638 -0.6870094537734985
# 0.9142118096351624 -0.6869693398475647
# 0.9142095446586609 -0.6869292259216309
# 0.9142072796821594 -0.686889111995697
# 0.914205014705658 -0.6868489980697632
# 0.9142027497291565 -0.6868088841438293
# 0.914200484752655 -0.6867687702178955
# 0.9141982793807983 -0.6867286562919617
# 0.9141960144042969 -0.6866885423660278
# 0.9141937494277954 -0.686648428440094
# 0.914191484451294 -0.6866083145141602
# 0.9141892194747925 -0.6865682005882263
# 0.914186954498291 -0.6865280866622925
# 0.9141846895217896 -0.6864879727363586
# 0.9141824245452881 -0.6864478588104248
# 0.9141801595687866 -0.686407744884491
# 0.9141779541969299 -0.6863676309585571
# 0.9141756892204285 -0.6863275170326233
# 0.914173424243927 -0.6862874031066895
# 0.9141711592674255 -0.6862472891807556
# 0.9141688942909241 -0.6862071752548218
# 0.9141666293144226 -0.6861670613288879
# 0.9141643643379211 -0.6861269474029541
# 0.9141621589660645 -0.6860868334770203
# 0.914159893989563 -0.6860467195510864
# 0.9141576290130615 -0.6860066056251526
# 0.9141553640365601 -0.6859664916992188
# 0.9141530990600586 -0.6859263777732849
# 0.9141508936882019 -0.6858862638473511
# 0.9141486287117004 -0.6858461499214172
# 0.914146363735199 -0.6858060956001282
# 0.9141440987586975 -0.6857660412788391
# 0.914141833782196 -0.68572598695755
# 0.9141396284103394 -0.685685932636261
# 0.9141373634338379 -0.6856458783149719
# 0.9141350984573364 -0.6856058239936829
# 0.914132833480835 -0.6855657696723938
# 0.9141306281089783 -0.6855257153511047
# 0.9141283631324768 -0.6854856610298157
# 0.9141260981559753 -0.6854456067085266
# 0.9141238331794739 -0.6854055523872375
# 0.9141216278076172 -0.6853654980659485
# 0.9141193628311157 -0.6853254437446594
# 0.9141170978546143 -0.6852853894233704
# 0.9141148328781128 -0.6852453351020813
# 0.9141125679016113 -0.6852052807807922
# 0.9141103625297546 -0.6851652264595032
# 0.9141080975532532 -0.6851251721382141
# 0.9141058325767517 -0.685085117816925
# 0.9141035676002502 -0.685045063495636
# 0.9141013622283936 -0.6850050091743469
# 0.9140990972518921 -0.6849649548530579
# 0.9140968322753906 -0.6849249005317688
# 0.9140945672988892 -0.6848848462104797
# 0.9140923023223877 -0.6848447918891907
# 0.9140900373458862 -0.6848047375679016
# 0.9140878319740295 -0.6847646832466125
# 0.9140855669975281 -0.6847246289253235
# 0.9140833020210266 -0.6846845746040344
# 0.9140810370445251 -0.6846445202827454
# 0.9140788316726685 -0.6846044659614563
# 0.914076566696167 -0.6845644116401672
# 0.9140743017196655 -0.6845243573188782
# 0.9140720367431641 -0.6844843029975891
# 0.9140697717666626 -0.6844442486763
# 0.9140675067901611 -0.684404194355011
# 0.9140653014183044 -0.6843641400337219
# 0.914063036441803 -0.6843240857124329
# 0.9140607714653015 -0.6842840313911438
# 0.9140585660934448 -0.6842439770698547
# 0.9140563011169434 -0.6842039227485657
# 0.9140540361404419 -0.6841639280319214
# 0.9140517711639404 -0.6841239333152771
# 0.914049506187439 -0.6840839385986328
# 0.9140473008155823 -0.6840439438819885
# 0.9140450358390808 -0.6840039491653442
# 0.9140427708625793 -0.6839639544487
# 0.9140405058860779 -0.6839239597320557
# 0.9140383005142212 -0.6838839650154114
# 0.9140360355377197 -0.6838439702987671
# 0.9140337705612183 -0.6838039755821228
# 0.9140315055847168 -0.6837639808654785
# 0.9140292406082153 -0.6837239861488342
# 0.9140270352363586 -0.6836839914321899
# 0.9140247702598572 -0.6836439967155457
# 0.9140225052833557 -0.6836040019989014
# 0.914020299911499 -0.6835640072822571
# 0.9140180349349976 -0.6835240125656128
# 0.9140157699584961 -0.6834840178489685
# 0.9140135049819946 -0.6834440231323242
# 0.9140112996101379 -0.6834040284156799
# 0.9140090346336365 -0.6833640336990356
# 0.9140068292617798 -0.6833240389823914
# 0.9140045642852783 -0.6832840442657471
# 0.9140022993087769 -0.6832440495491028
# 0.9140000343322754 -0.6832040548324585
# 0.9139978289604187 -0.6831640601158142
# 0.9139955639839172 -0.6831240653991699
# 0.9139932990074158 -0.6830840706825256
# 0.9139910936355591 -0.6830440759658813
# 0.9139888286590576 -0.6830040812492371
# 0.9139865636825562 -0.6829640865325928
# 0.9139842987060547 -0.6829240918159485
# 0.913982093334198 -0.6828840970993042
# 0.9139798283576965 -0.6828441023826599
# 0.9139775633811951 -0.6828041076660156
# 0.9139752984046936 -0.6827641129493713
# 0.9139730334281921 -0.682724118232727
# Learned weight (w): 0.9139708280563354
# Learned bias (b): -0.6826841235160828

# %% [markdown]
# ## Q6

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

X1 = torch.tensor([3, 4, 5, 6, 2]).view(-1, 1).float()
X2 = torch.tensor([8, 5, 7, 3, 1]).view(-1, 1).float()
Y = torch.tensor([-3.7, 3.5, 2.5, 11.5, 5.7]).view(-1, 1).float()
iters = 1000

X = torch.cat((X1, X2), dim=1)

class MLR(nn.Module):
    def __init__(self):
        super(MLR, self).__init__()
        self.linear = nn.Linear(2, 1)  # 2 features, 1 output

    def forward(self, x):
        return self.linear(x)

model = MLR()
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.001)

# List to store the loss values for plotting
loss_list = []
for epoch in range(iters):
    model.train()

    # Forward pass
    Y_pred = model(X)
    loss = criterion(Y_pred, Y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    loss_list.append(loss.item())

plt.plot(loss_list, 'r')
plt.tight_layout()
plt.xlabel("Epochs/Iterations")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.show()

print("Learned weight (w):", model.linear.weight, model.linear.weight.grad)
print("Learned bias (b):", model.linear.bias, model.linear.bias.grad.item())
# Out:
# Learned weight (w): Parameter containing:
# tensor([[ 2.5535, -1.5876]], requires_grad=True) tensor([[0.0222, 0.0347]])
# Learned bias (b): Parameter containing:
# tensor([1.1608], requires_grad=True) -0.29169249534606934

# %% [markdown]
# ## Q7

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

X = torch.tensor([1, 5, 10, 10, 25, 50, 70, 75, 100]).view(-1, 1).float()  # Features
y = torch.tensor([0, 0, 0, 0, 0, 1, 1, 1, 1]).view(-1, 1).float()  # Target labels

class LogisticRegression(nn.Module):
    def __init__(self):
        super(LogisticRegression, self).__init__()
        self.linear = nn.Linear(1, 1)

    def forward(self, x):
        return torch.sigmoid(self.linear(x))  # sigmoid activation


model = LogisticRegression()
criterion = nn.BCELoss()
optimizer = optim.SGD(model.parameters(), lr=0.001)
loss_list = []

# Training loop
epochs = 1000
for epoch in range(epochs):
    model.train()

    y_pred = model(X)
    loss = criterion(y_pred, y)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()


    loss_list.append(loss.item())

plt.plot(loss_list)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.show()

with torch.no_grad():
    y_pred_final = model(X)


print("Learned weight (w):", model.linear.weight.item())#, model.linear.weight.grad)
print("Learned bias (b):", model.linear.bias.item())#,model.linear.bias.grad)

test_input = torch.tensor([[30.0]]).float()
predicted_prob = model(test_input).item()
print(f"Predicted probability for input 30: {predicted_prob:.4f}")
# Out:
# Learned weight (w): 0.034797318279743195
# Learned bias (b): -0.33471909165382385
# Predicted probability for input 30: 0.6702
